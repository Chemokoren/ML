# %%
# Importing libraries
import pandas as pd    
import numpy as np

# %%
# Reading data to Dataframes
    
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
data_check = pd.read_csv('test_result.csv')

# %%
#changing column name
    
data_train = data_train.rename(columns = {'Pclass' : 'TicketClass'})
data_test = data_test.rename(columns = {'Pclass' : 'TicketClass'})

# %%
#Removing unused columns
data_train = data_train.drop(['Name','Ticket','Fare','Cabin','Embarked','Age'],axis =1)
data_test = data_test.drop(['Name','Age','Ticket','Fare','Cabin','Embarked'], axis =1)

# %%
#Importing LabelEncoder from Sklearn
from sklearn.preprocessing import LabelEncoder
label_encoder_sex = LabelEncoder()
# Out:
#    PassengerId  TicketClass  Sex  SibSp  Parch
# 0          892            2    1      0      0
# 1          893            2    0      1      0
# 2          894            1    1      0      0
# 3          895            2    1      0      0
# 4          896            2    0      1      1

# %%
# Transforming sex column values using label Encoder
data_train.iloc[:,3]  = label_encoder_sex.fit_transform(data_train.iloc[:,3])
data_test.iloc[:,2] = label_encoder_sex.fit_transform(data_test.iloc[:,2])

# %%
data_train = data_train[['PassengerId','Sex','SibSp','Parch','TicketClass','Survived']]
data_test = data_test[['PassengerId','Sex','SibSp','Parch','TicketClass']]

# %%
data_train.head()
# Out:
#    PassengerId  Sex  SibSp  Parch  TicketClass  Survived
# 0            1    1      1      0            3         0
# 1            2    0      1      0            1         1
# 2            3    0      0      0            3         1
# 3            4    0      1      0            1         1
# 4            5    1      0      0            3         0

# %%
X_train = data_train.iloc[:,0:4]   # Inputs
y_train = data_train.iloc[:,5]     #Output (Survived)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(data_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
#Input layer with 5 inputs neurons
classifier.add(Dense(output_dim = 3, init = 'uniform', activation = 'relu', input_dim = 5))
#Hidden layer
classifier.add(Dense(output_dim = 2, init = 'uniform', activation = 'relu'))
#output layer with 1 output neuron which will predict 1 or 0
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-7776bf427868> in <module>
#       1 #Input layer with 5 inputs neurons
# ----> 2 classifier.add(Dense(units=3,output_dim = 3, init = 'uniform', activation = 'relu', input_dim = 5))
#       3 #Hidden layer
#       4 classifier.add(Dense(output_dim = 2, init = 'uniform', activation = 'relu'))
#       5 #output layer with 1 output neuron which will predict 1 or 0
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#    1155                bias_constraint=None,
#    1156                **kwargs):
# -> 1157     super(Dense, self).__init__(
#    1158         activity_regularizer=activity_regularizer, **kwargs)
#    1159
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     338     }
#     339     # Validate optional keyword arguments.
# --> 340     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     341
#     342     # Mutable properties
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     806   for kwarg in kwargs:
#     807     if kwarg not in allowed_kwargs:
# --> 808       raise TypeError(error_message, kwarg)
#     809
#     810
#
# TypeError: ('Keyword argument not understood:', 'output_dim')

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9939 - accuracy: 0.2378
# Epoch 2/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0131 - accuracy: 0.2312
# Epoch 3/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.2313 - accuracy: 0.2497
# Epoch 4/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8685 - accuracy: 0.2382
# Epoch 5/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8973 - accuracy: 0.2309
# Epoch 6/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0147 - accuracy: 0.2107
# Epoch 7/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1918 - accuracy: 0.2295
# Epoch 8/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0553 - accuracy: 0.2412
# Epoch 9/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7671 - accuracy: 0.2212
# Epoch 10/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8309 - accuracy: 0.2514
# Epoch 11/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0874 - accuracy: 0.2285
# Epoch 12/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9782 - accuracy: 0.2444
# Epoch 13/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8191 - accuracy: 0.2428
# Epoch 14/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9235 - accuracy: 0.2295
# Epoch 15/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9380 - accuracy: 0.2209
# Epoch 16/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8174 - accuracy: 0.2373
# Epoch 17/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0288 - accuracy: 0.2340
# Epoch 18/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8601 - accuracy: 0.2321
# Epoch 19/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0591 - accuracy: 0.2324
# Epoch 20/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8864 - accuracy: 0.2500
# Epoch 21/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9347 - accuracy: 0.2489
# Epoch 22/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9501 - accuracy: 0.2332
# Epoch 23/100
# 90/90 [==============================] - 0s 964us/step - loss: 4.8586 - accuracy: 0.2595
# Epoch 24/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.2201 - accuracy: 0.2304
# Epoch 25/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0090 - accuracy: 0.2369
# Epoch 26/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0358 - accuracy: 0.2512
# Epoch 27/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8968 - accuracy: 0.2374
# Epoch 28/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8696 - accuracy: 0.2434
# Epoch 29/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0185 - accuracy: 0.2291
# Epoch 30/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0366 - accuracy: 0.2152
# Epoch 31/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8862 - accuracy: 0.2409
# Epoch 32/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8133 - accuracy: 0.2515
# Epoch 33/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1521 - accuracy: 0.2550
# Epoch 34/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9655 - accuracy: 0.2051
# Epoch 35/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8859 - accuracy: 0.2242
# Epoch 36/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9611 - accuracy: 0.2294
# Epoch 37/100
# 90/90 [==============================] - 0s 982us/step - loss: 5.3396 - accuracy: 0.2385
# Epoch 38/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7318 - accuracy: 0.2130
# Epoch 39/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9171 - accuracy: 0.2192
# Epoch 40/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8997 - accuracy: 0.2296
# Epoch 41/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9716 - accuracy: 0.2200
# Epoch 42/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7777 - accuracy: 0.2356
# Epoch 43/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9077 - accuracy: 0.2203
# Epoch 44/100
# 90/90 [==============================] - 0s 980us/step - loss: 4.8914 - accuracy: 0.2557
# Epoch 45/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1764 - accuracy: 0.2500
# Epoch 46/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9058 - accuracy: 0.2190
# Epoch 47/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9608 - accuracy: 0.2344
# Epoch 48/100
# 90/90 [==============================] - 0s 979us/step - loss: 4.9156 - accuracy: 0.2610
# Epoch 49/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8491 - accuracy: 0.2366
# Epoch 50/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8053 - accuracy: 0.2210
# Epoch 51/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9339 - accuracy: 0.2350
# Epoch 52/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8692 - accuracy: 0.2146
# Epoch 53/100
# 90/90 [==============================] - 0s 2ms/step - loss: 4.7916 - accuracy: 0.2236
# Epoch 54/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.2606 - accuracy: 0.2182
# Epoch 55/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0079 - accuracy: 0.2342
# Epoch 56/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8680 - accuracy: 0.2469
# Epoch 57/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9701 - accuracy: 0.2279
# Epoch 58/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7951 - accuracy: 0.2478
# Epoch 59/100
# 90/90 [==============================] - 0s 955us/step - loss: 4.7693 - accuracy: 0.2500
# Epoch 60/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9963 - accuracy: 0.2303
# Epoch 61/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1153 - accuracy: 0.2448
# Epoch 62/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9105 - accuracy: 0.2460
# Epoch 63/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0687 - accuracy: 0.2240
# Epoch 64/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8248 - accuracy: 0.2167
# Epoch 65/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9276 - accuracy: 0.2385
# Epoch 66/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9104 - accuracy: 0.2434
# Epoch 67/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1589 - accuracy: 0.2423
# Epoch 68/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7276 - accuracy: 0.2444
# Epoch 69/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7054 - accuracy: 0.2260
# Epoch 70/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7826 - accuracy: 0.2194
# Epoch 71/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8113 - accuracy: 0.2455
# Epoch 72/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9291 - accuracy: 0.2221
# Epoch 73/100
# 90/90 [==============================] - 0s 982us/step - loss: 4.9990 - accuracy: 0.2380
# Epoch 74/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1888 - accuracy: 0.2296
# Epoch 75/100
# 90/90 [==============================] - 0s 943us/step - loss: 4.9972 - accuracy: 0.2162
# Epoch 76/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0997 - accuracy: 0.2342
# Epoch 77/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7885 - accuracy: 0.1990
# Epoch 78/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8424 - accuracy: 0.2419
# Epoch 79/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0182 - accuracy: 0.2374
# Epoch 80/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0245 - accuracy: 0.2376
# Epoch 81/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9040 - accuracy: 0.2356
# Epoch 82/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0642 - accuracy: 0.2112
# Epoch 83/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9444 - accuracy: 0.2441
# Epoch 84/100
# 90/90 [==============================] - 0s 966us/step - loss: 5.2066 - accuracy: 0.2401
# Epoch 85/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0668 - accuracy: 0.2250
# Epoch 86/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.2018 - accuracy: 0.2440
# Epoch 87/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9053 - accuracy: 0.2413
# Epoch 88/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8275 - accuracy: 0.2196
# Epoch 89/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8364 - accuracy: 0.2301
# Epoch 90/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0119 - accuracy: 0.2497
# Epoch 91/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7890 - accuracy: 0.2539
# Epoch 92/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.2469 - accuracy: 0.2362
# Epoch 93/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7981 - accuracy: 0.2393
# Epoch 94/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0712 - accuracy: 0.2228
# Epoch 95/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.7785 - accuracy: 0.2469
# Epoch 96/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.0060 - accuracy: 0.2366
# Epoch 97/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.8922 - accuracy: 0.2269
# Epoch 98/100
# 90/90 [==============================] - 0s 1ms/step - loss: 4.9553 - accuracy: 0.2154
# Epoch 99/100
# 90/90 [==============================] - 0s 988us/step - loss: 5.0216 - accuracy: 0.2287
# Epoch 100/100
# 90/90 [==============================] - 0s 1ms/step - loss: 5.1444 - accuracy: 0.2286

# %%
#getting predictions of test data
prediction = classifier.predict(X_test).tolist()
# list to series
se = pd.Series(prediction)
# creating new column of predictions in data_check dataframe
data_check['check'] = se
data_check['check'] = data_check['check'].str.get(0)

# %%
data_check
# Out:
#      PassengerId  Survived     check
# 0            892         0 -1.727912
# 1            893         1 -1.719625
# 2            894         0 -1.711337
# 3            895         0 -1.703050
# 4            896         1 -1.694763
# ..           ...       ...       ...
# 413         1305         0  1.694763
# 414         1306         1  1.703050
# 415         1307         0  1.711337
# 416         1308         0  1.719625
# 417         1309         0  1.727912
#
# [418 rows x 3 columns]

# %%
series = []
for val in data_check.check:
    if val >= 0.5:
        series.append(1)
    else:
        series.append(0)
data_check['final'] = series

# %%
data_check
# Out:
#      PassengerId  Survived     check  final
# 0            892         0 -1.727912      0
# 1            893         1 -1.719625      0
# 2            894         0 -1.711337      0
# 3            895         0 -1.703050      0
# 4            896         1 -1.694763      0
# ..           ...       ...       ...    ...
# 413         1305         0  1.694763      1
# 414         1306         1  1.703050      1
# 415         1307         0  1.711337      1
# 416         1308         0  1.719625      1
# 417         1309         0  1.727912      1
#
# [418 rows x 4 columns]

# %%
match = 0
nomatch = 0
for val in data_check.values:
    if val[1] == val[3]:
        match = match +1
    else:
        nomatch = nomatch +1

# %%
print(match,nomatch)
# Out:
# 219 199
